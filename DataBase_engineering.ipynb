# %%
import pandas as pd
from sqlalchemy import create_engine , func , inspect , Date
from sqlalchemy.orm import Session 
from sqlalchemy.ext.declarative import declarative_base
import sqlalchemy 
from sqlalchemy import Column, Integer, String, Float

# %%
engine= create_engine("sqlite:///hawaii.sqlite")
Base= declarative_base()

# %%
Base = declarative_base()
class Measurement(Base):
    __tablename__ = "measurement"
    
    id = Column(Integer, primary_key=True)
    station = Column(String)
    date = Column(String) 
    prcp = Column(Float) 
    tobs = Column(Float) 
class Station(Base):
    __tablename__ = "station"
    
    id = Column(Integer, primary_key=True)
    station = Column(String)
    name = Column(String) 
    latitude = Column(Float) 
    longitude = Column(Float) 
    elevation = Column(Float)

# %%
engine = create_engine("sqlite:///hawaii.sqlite")
Base.metadata.create_all(engine)

# %%
test = pd.read_csv('clean_measurements.csv')
test.head()
# Out:
#    Unnamed: 0      station        date  prcp  tobs
# 0           0  USC00519397  2010-01-01  0.08    65
# 1           1  USC00519397  2010-01-02  0.00    63
# 2           2  USC00519397  2010-01-03  0.00    74
# 3           3  USC00519397  2010-01-04  0.00    76
# 4           4  USC00519397  2010-01-06   NaN    73

# %%
list(Measurement.__table__.columns)
# Out:
# [Column('id', Integer(), table=<measurement>, primary_key=True, nullable=False),
#  Column('station', String(), table=<measurement>),
#  Column('date', String(), table=<measurement>),
#  Column('prcp', Float(), table=<measurement>),
#  Column('tobs', Float(), table=<measurement>)]

# %%
def populate_table (engine, table, csvfile):
    conn = engine.connect() 
    
    df_insert = pd.read_csv(csvfile)
    
    data = df_insert.to_dict(orient='records')
   
    conn.execute(table.insert(), data)
populate_table(engine, Measurement.__table__,'clean_measurements.csv')
populate_table(engine, Station.__table__,'clean_station.csv')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1158                         parameters,
# -> 1159                         context)
#    1160             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     466     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 467         cursor.executemany(statement, parameters)
#     468
#
# OperationalError: table measurement has no column named prcp
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-29-d83bb0337498> in <module>()
# ...

# %%
engine.execute("SELECT * FROM measurement").fetchall()
# Out:
# []

# %%
engine.table_names()
# Out:
# ['Measurement', 'Station']

# %%
# Create Session and connect to corresponding database
session= Session(bind=engine)
populate_table(engine, Station.__table__, 'clean_hawaii_stations.csv')
populate_table(engine, Measurement.__table__, 'clean_hawaii_measurements.csv')

# %%
# Read CSv file to pd and convert it to dict 
#ms_dict=df_ms.to_dict(orient="records")
#st_dict = df_st.to_dict(orient="records")

# %%
#conn.execute(Measurements.__table__.insert(), ms_dict)
#conn.execute(Stations.__table__.insert(), st_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1115
# -> 1116             context = constructor(dialect, self, conn, *args)
#    1117         except BaseException as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in _init_compiled(cls, dialect, connection, dbapi_connection, compiled, parameters)
#     622                     if key in processors:
# --> 623                         param.append(processors[key](compiled_params[key]))
#     624                     else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py in process(value)
#     670             else:
# --> 671                 raise TypeError("SQLite Date type only accepts Python "
# ...

# %%
engine.execute("Select * from Stations").fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# OperationalError: no such table: Stations
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-212-118f97755fad> in <module>()
# ...

# %%
for index, row in df_ms.iterrows():
    measur=Measurements( station=row['station'],date=row['date'],
                    prcp=row['prcp'],tobs=row['tobs'])
    session.add(measur)
session.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1158                         parameters,
# -> 1159                         context)
#    1160             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     466     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 467         cursor.executemany(statement, parameters)
#     468
#
# OperationalError: table Measurement has no column named prcp
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-197-9ee2ef533e24> in <module>()
# ...

# %%
session.rollback()
for index, row in df_st.iterrows():
    sta=Stations(id=index, station=row['station'],name=row['name'],
                latitude=row['latitude'],longitude=row['longitude'],
                elevation=row['elevation'])
    session.add(sta)
session.commit()
# Out:
# C:\Users\Bachra Yara minek 10\Anaconda3\lib\site-packages\sqlalchemy\orm\session.py:507: SAWarning: Session's state has been changed on a non-active transaction - this state will be discarded.
#   "Session's state has been changed on "
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1158                         parameters,
# -> 1159                         context)
#    1160             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     466     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 467         cursor.executemany(statement, parameters)
#     468
#
# ...
